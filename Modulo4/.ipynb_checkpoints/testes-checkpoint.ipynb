# %% [markdown]
# Define o valor de `a`

# %%
a = 10

# %% [markdown]
# Define o valor de `b`

# %%
b = 15

# %% [markdown]
# Realiza a soma entre `a + b`

# %%
soma = a + b

# %% [markdown]
# Exibe a soma

# %%
soma
# Out:
# 25
